# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import pylab as plt

df = pd.read_excel('data/weatherAUS.xlsx')
#df.head(10) #<- shows the first 10 entries
#time dependent data

# %%
df.head()
# Out:
#         Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0 2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1 2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2 2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3 2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4 2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# ...

# %%
df.shape
# Out:
# (142193, 24)

# %%
X = df.loc[df['Location'] == 'Canberra']

# %%
X.shape
# Out:
# (3418, 24)

# %%
X.head()
# Out:
#             Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 44351 2007-11-01  Canberra      8.0     24.3       0.0          3.4       6.3
# 44352 2007-11-02  Canberra     14.0     26.9       3.6          4.4       9.7
# 44353 2007-11-03  Canberra     13.7     23.4       3.6          5.8       3.3
# 44354 2007-11-04  Canberra     13.3     15.5      39.8          7.2       9.1
# 44355 2007-11-05  Canberra      7.6     16.1       2.8          5.6      10.6
#
#       WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 44351          NW           30.0         SW  ...        29.0       1019.7
# 44352         ENE           39.0          E  ...        36.0       1012.4
# 44353          NW           85.0          N  ...        69.0       1009.5
# 44354          NW           54.0        WNW  ...        56.0       1005.5
# 44355         SSE           50.0        SSE  ...        49.0       1018.3
#
# ...

# %%
X.count().sort_values()
# Out:
# Sunshine         1512
# Evaporation      1823
# Cloud3pm         2164
# Cloud9am         2352
# WindDir9am       2882
# WindGustDir      3089
# WindGustSpeed    3091
# WindDir3pm       3190
# WindSpeed9am     3190
# Pressure9am      3194
# WindSpeed3pm     3195
# Pressure3pm      3198
# Humidity9am      3357
# Temp9am          3401
# RainToday        3402
# Rainfall         3402
# Humidity3pm      3406
# Temp3pm          3411
# MinTemp          3413
# MaxTemp          3415
# Date             3418
# Location         3418
# RISK_MM          3418
# RainTomorrow     3418
# dtype: int64

# %%
X = X.drop(columns=['Evaporation','Sunshine','RainTomorrow'],axis=1)

# %%
X.head()
# Out:
#             Date  Location  MinTemp  MaxTemp  Rainfall WindGustDir  \
# 44351 2007-11-01  Canberra      8.0     24.3       0.0          NW
# 44352 2007-11-02  Canberra     14.0     26.9       3.6         ENE
# 44353 2007-11-03  Canberra     13.7     23.4       3.6          NW
# 44354 2007-11-04  Canberra     13.3     15.5      39.8          NW
# 44355 2007-11-05  Canberra      7.6     16.1       2.8         SSE
#
#        WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity9am  \
# 44351           30.0         SW         NW           6.0  ...         68.0
# 44352           39.0          E          W           4.0  ...         80.0
# 44353           85.0          N        NNE           6.0  ...         82.0
# 44354           54.0        WNW          W          30.0  ...         62.0
# 44355           50.0        SSE        ESE          20.0  ...         68.0
#
#        Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# ...

# %%
Y = X.RISK_MM
X = X.drop('RISK_MM',axis=1)

# %%
print(Y.shape)
X.shape
# Out:
# (3418,)
# (3418, 20)

# %%
X = X.fillna(0)

# %%
X.count().sort_values()
# Out:
# Date             3418
# Temp9am          3418
# Cloud3pm         3418
# Cloud9am         3418
# Pressure3pm      3418
# Pressure9am      3418
# Humidity3pm      3418
# Humidity9am      3418
# WindSpeed3pm     3418
# WindSpeed9am     3418
# WindDir3pm       3418
# WindDir9am       3418
# WindGustSpeed    3418
# WindGustDir      3418
# Rainfall         3418
# MaxTemp          3418
# MinTemp          3418
# Location         3418
# Temp3pm          3418
# RainToday        3418
# dtype: int64
